# %% [markdown]
# ## Notebook to Generate all our Plots

# %% [markdown]
# Importing the police data:

# %%
import numpy as np
import pandas as pd

data = pd.read_csv("../PoliceData.csv") 
data['Date']= pd.to_datetime(data['Date']) # Make the date column date datatype
data['Time']= pd.to_datetime(data['Time']) # Make the time column date datatype

data['Category'] = data['Category'].replace('DRIVING UNDER THE INFLUENCE', 'DUI')
# Out:
# C:\Users\Bruger\AppData\Local\Temp\ipykernel_25476\2371710559.py:6: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Time']= pd.to_datetime(data['Time']) # Make the time column date datatype

# %% [markdown]
# Filtering for the drug/narcotic crimes and seeing all the different descriptions:

# %%
drugCrimes = data[data['Category'] == 'DRUG/NARCOTIC']
print(drugCrimes['Descript'].unique())

drugCrimeTypes = drugCrimes['Descript'].unique()
print(len(drugCrimeTypes))
# Out:
# ['POSSESSION OF HEROIN' 'POSSESSION OF METH-AMPHETAMINE'
#  'POSSESSION OF NARCOTICS PARAPHERNALIA' 'PLANTING/CULTIVATING MARIJUANA'
#  'CONTROLLED SUBSTANCE VIOLATION, LOITERING FOR' 'POSSESSION OF MARIJUANA'
#  'POSSESSION OF HEROIN FOR SALES'
#  'POSSESSION OF BASE/ROCK COCAINE FOR SALE' 'SALE OF CONTROLLED SUBSTANCE'
#  'POSSESSION OF BASE/ROCK COCAINE' 'POSSESSION OF COCAINE'
#  'SALE OF MARIJUANA' 'SALE OF BASE/ROCK COCAINE'
#  'POSSESSION OF MARIJUANA FOR SALES'
#  'POSSESSION OF METH-AMPHETAMINE FOR SALE'
#  'POSSESSION OF CONTROLLED SUBSTANCE'
#  'LOITERING WHERE NARCOTICS ARE SOLD/USED' 'POSSESSION OF METHADONE'
#  'UNDER THE INFLUENCE OF CONTROLLED SUBSTANCES'
#  'TRANSPORTATION OF MARIJUANA' 'FORGE OR ALTER PRESCRIPTION'
#  'POSSESSION OF OPIATES' 'SALE OF HEROIN' 'POSSESSION OF AMPHETAMINE'
#  'POSSESSION OF CONTROLLED SUBSTANCE FOR SALE' 'SALE OF AMPHETAMINE'
#  'SALES COCAINE BASE/SCHOOLYARD TRAFFICKING ACT VIO'
#  'MAINTAINING PREMISE WHERE NARCOTICS ARE SOLD/USED'
#  'POSSESSION OF COCAINE FOR SALES' 'SALE OF METH-AMPHETAMINE'
#  'UNDER INFLUENCE OF DRUGS IN A PUBLIC PLACE' 'TRANSPORTATION OF COCAINE'
#  'POSSESSION OF OPIUM DERIVATIVE' 'SALE OF COCAINE' 'FURNISHING MARIJUANA'
#  'TRANSPORTATION OF HEROIN' 'POSSESSION OF HALLUCINOGENIC'
#  'POSSESSION OF HALLUCINOGENIC FOR SALES'
#  'POSSESSION OF AMPHETAMINE FOR SALES'
#  'TRANSPORTAION OF CONTROLLED SUBSTANCE' 'POSSESSION OF OPIATES FOR SALES'
#  'POSSESSION OF METHADONE FOR SALES' 'TRANSPORTATION OF METH-AMPHETAMINE'
#  'SALE OF OPIATES' 'POSSESSION OF OPIUM'
#  'HYPODERMIC NEEDLE OR SYRINGE, POSSESSION'
#  'POSSESSION OF OPIUM DERIVATIVE FOR SALES'
#  'VISITING WHERE DRUGS ARE USED OR SMOKED'
#  'DRUG LAB APPARATUS, POSSESSION' 'SALE OF HALLUCINOGENIC'
#  'FAILURE TO REGISTER AS NARCOTICS ADDICT' 'TRANSPORTATION OF AMPHETAMINE'
#  'PRESCRIPTION, FORGE OR ALTER (4390 B&P)' 'SALE OF METHADONE'
#  'MONEY OFFENSE RELATED TO NARCOTICS TRAFFICKING'
#  'POSSESSION OF OPIUM FOR SALES' 'POSSESSION OF BARBITUATES'
#  'SALE OF OPIUM DERIVATIVE' 'SALE OF BARBITUATES'
#  'TRANSPORTATION OF HALLUCINOGENIC' 'POSSESSION OF BARBITUATES FOR SALES'
#  'SALE OF OPIUM' 'TRANSPORTATION OF METHADONE' 'TRANSPORTATION OF OPIATES'
#  'TRANSPORTATION OF OPIUM DERIVATIVE' 'TRANSPORTATION OF OPIUM'
#  'PLANTING/CULTIVATING PEYOTE']
# 67

# %% [markdown]
# Adding labels based on description for the drug type:

# %%
import numpy as np

# Define conditions and corresponding labels
conditions = [
    drugCrimes['Descript'].str.contains('heroin', case=False),
    drugCrimes['Descript'].str.contains('opium|opiates', case=False),
    drugCrimes['Descript'].str.contains('prescription', case=False),
    drugCrimes['Descript'].str.contains('meth-amphetamine', case=False),
    drugCrimes['Descript'].str.contains('amphetamine', case=False),
    drugCrimes['Descript'].str.contains('methadone', case=False),
    drugCrimes['Descript'].str.contains('marijuana', case=False),
    drugCrimes['Descript'].str.contains('base/rock cocaine', case=False),
    drugCrimes['Descript'].str.contains('cocaine', case=False),
    drugCrimes['Descript'].str.contains('barbituates', case=False),
    drugCrimes['Descript'].str.contains('hallucinogenic', case=False),
    drugCrimes['Descript'].str.contains('narcotics|substance', case=False),
]

labels = ['Heroin', 'Opium/Opiates', 'Prescription', 'Methamphetamine', 'Amphetamine', 'Methadone', 'Marijuana', 'Base/rock cocaine', 'Cocaine', 'Barbituates', 'Hallucinogenic', 'Narcotics/Substance']

# Apply conditions and assign labels
drugCrimes.loc[:, 'drugtype'] = np.select(conditions, labels, default='Other')

# Print unique values of the 'drugtype' column for verification
drugCrimes[['drugtype', 'Descript']].head()
# Out:
#                 drugtype                               Descript
# 18                Heroin                   POSSESSION OF HEROIN
# 31       Methamphetamine         POSSESSION OF METH-AMPHETAMINE
# 37   Narcotics/Substance  POSSESSION OF NARCOTICS PARAPHERNALIA
# 80   Narcotics/Substance  POSSESSION OF NARCOTICS PARAPHERNALIA
# 167            Marijuana         PLANTING/CULTIVATING MARIJUANA

# %% [markdown]
# Normalising count for every drug type for every year:

# %%
labels.append("Other")

yearGroups = pd.DataFrame()
yearGroups.index.name = 'Year'

drugCrimesFilter = drugCrimes[drugCrimes['Date'].dt.year != 2018]

for i in labels:
    drugCrime = drugCrimesFilter[drugCrimesFilter['drugtype'] == i]
    yearCount = drugCrime.groupby(drugCrime['Date'].dt.year).size()
    yearTotal = yearCount.sum()
    yearGroups[i] = yearCount / yearTotal

yearGroups = yearGroups.fillna(0)
yearGroups.head()
# Out:
#         Heroin  Opium/Opiates  Prescription  Methamphetamine  Amphetamine  \
# Year
# 2003  0.082205       0.061166      0.082734         0.060631     0.180970
# 2004  0.079349       0.044097      0.064748         0.053113     0.176306
# 2005  0.063206       0.046942      0.043165         0.056137     0.138993
# 2006  0.063206       0.031294      0.039568         0.046004     0.117537
# 2007  0.084441       0.056899      0.025180         0.047393     0.136194
#
#       Methadone  Marijuana  Base/rock cocaine   Cocaine  Barbituates  \
# Year
# 2003   0.019048   0.085453           0.101849  0.085769     0.000000
# 2004   0.022222   0.080934           0.107146  0.085077     0.000000
# 2005   0.015873   0.057683           0.095350  0.078506     0.000000
# 2006   0.025397   0.063042           0.100972  0.080062     0.045455
# 2007   0.038095   0.087271           0.113061  0.082829     0.090909
#
#       Hallucinogenic  Narcotics/Substance     Other
# Year
# 2003        0.053846             0.072924  0.142064
# 2004        0.041538             0.076648  0.100999
# 2005        0.049231             0.068115  0.075472
# 2006        0.061538             0.077440  0.109878
# 2007        0.075385             0.086295  0.077691

# %% [markdown]
# ## Plot 1: Normalised Count Time Series
#
# Interactive bokeh time series based on the prior table:

# %%
from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource, Legend
from bokeh.io import output_notebook, output_file
from bokeh.palettes import Category20_14

yearGroups.index = yearGroups.index.astype(str)

# Create a Bokeh ColumnDataSource from the DataFrame
source = ColumnDataSource(yearGroups)

output_file("TimeSeries.html")

# Create a Bokeh figure
p = figure(x_range=yearGroups.index.values, height=400, width=800, title="Normalized Yearly Drug Crime Counts",
           toolbar_location=None, tools="", y_axis_label="Normalized Count")

# Create an empty Legend object
legend = Legend()

# Add the legend to the plot on the right side
p.add_layout(legend, 'right')

# Plot vertical bars for each crime category
categories = list(yearGroups.columns)

palette = [color for color in Category20_14]

bar = {}

for idx, i in enumerate(categories):
    bar[i] = p.vbar(x='Year', top=i, source=source, width=0.5, legend_label=i,
           color=palette[idx], muted_color=palette[idx], fill_alpha=0.8, 
           muted_alpha=0.1, muted=True)

# Set attributes for the plot
p.y_range.start = 0
p.xaxis.axis_label = "Year"
p.yaxis.axis_label = "Normalized Count"
p.legend.click_policy = "mute"
p.title.text_font = "Helvetica"
p.title.align = "center"
p.xaxis.axis_label_text_font = "Helvetica"
p.yaxis.axis_label_text_font = "Helvetica"
p.legend.label_text_font = "Helvetica"

# Show the plot
output_notebook()
show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="e87af181-edda-4afe-89a7-f8bb92e26fcf">Loading BokehJS ...</span>
#     </div>
#   <div id="efe3983d-a056-475c-89f2-fe02478b986d" data-root-id="p1176" style="display: contents;"></div>

# %% [markdown]
# Filtering for a specific month and coloring by drug type:

# %%
monthData1 = drugCrimes[drugCrimes['Date'].dt.year == 2014]
monthData = monthData1[monthData1['Date'].dt.month == 4]
locationData = monthData[['X', 'Y', 'drugtype', 'Descript', 'Date']]
locationData['Date'] = locationData['Date'].astype(str)

# Provided lists
drug_types = ['Heroin', 'Opium/Opiates', 'Prescription', 'Methamphetamine', 'Amphetamine', 'Methadone', 'Marijuana', 'Base/rock cocaine', 'Cocaine', 'Barbituates', 'Hallucinogenic', 'Narcotics/Substance', 'Other']
hex_colors = ['#1f77b4', '#aec7e8', '#ff7f0e', '#ffbb78', '#2ca02c', '#98df8a', '#d62728', '#ff9896', '#9467bd', '#c5b0d5', '#8c564b', '#c49c94', '#e377c2', '#f7b6d2']
# Convert hexadecimal color codes to RGB values
rgb_colors = [tuple(int(hex_color[i:i+2], 16) for i in (1, 3, 5)) for hex_color in hex_colors]

# Create a dictionary to map drug types to colors
drug_type_color_mapping = dict(zip(drug_types, rgb_colors))

# Function to get the color based on drug type
def get_color(drugtype):
    return drug_type_color_mapping.get(drugtype, [255, 140, 0])  # Default color for unknown types

# Add a new column 'color' to the DataFrame using the 'drugtype' column
locationData['color'] = locationData['drugtype'].map(get_color)

# Define the amount of jitter (adjust as needed)
jitter_amount = 0.00017  # You can adjust this value based on your preference

# Function to add jitter to coordinates
def add_jitter(coord):
    return coord + np.random.uniform(-jitter_amount, jitter_amount)

# Identify rows where both X and Y coordinates match
duplicates_mask = locationData.duplicated(subset=['X', 'Y'], keep=False)

# Apply jitter to X and Y coordinates where both X and Y match
locationData['X'] = np.where(locationData.duplicated(subset=['X'], keep=False), 
                             locationData['X'].apply(add_jitter),
                             locationData['X'])

locationData['Y'] = np.where(locationData.duplicated(subset=['Y'], keep=False), 
                             locationData['Y'].apply(add_jitter),
                             locationData['Y'])

locationData.head()
# Out:
# C:\Users\Bruger\AppData\Local\Temp\ipykernel_25476\4058756103.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locationData['Date'] = locationData['Date'].astype(str)
# C:\Users\Bruger\AppData\Local\Temp\ipykernel_25476\4058756103.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locationData['color'] = locationData['drugtype'].map(get_color)
# C:\Users\Bruger\AppData\Local\Temp\ipykernel_25476\4058756103.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locationData['X'] = np.where(locationData.duplicated(subset=['X'], keep=False),
# C:\Users\Bruger\AppData\Local\Temp\ipykernel_25476\4058756103.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locationData['Y'] = np.where(locationData.duplicated(subset=['Y'], keep=False),
#                   X          Y           drugtype  \
# 1451095 -122.405829  37.768475    Methamphetamine
# 1451167 -122.417922  37.785120  Base/rock cocaine
# 1451438 -122.391523  37.732432             Heroin
# 1451946 -122.395357  37.738262            Cocaine
# 1451968 -122.407671  37.780099             Heroin
#
#                                Descript        Date            color
# 1451095  POSSESSION OF METH-AMPHETAMINE  2014-04-03  (255, 187, 120)
# 1451167       SALE OF BASE/ROCK COCAINE  2014-04-22  (255, 152, 150)
# 1451438            POSSESSION OF HEROIN  2014-04-24   (31, 119, 180)
# 1451946           POSSESSION OF COCAINE  2014-04-24  (148, 103, 189)
# 1451968            POSSESSION OF HEROIN  2014-04-03   (31, 119, 180)

# %% [markdown]
# ## Plot 2: Geo Scatter colored by Drug Type

# %%
import pydeck as pdk
import pandas as pd
import math

# Define a layer to display on a map
layer = pdk.Layer(
    "ScatterplotLayer",
    locationData,
    pickable=True,
    opacity=0.3,
    stroked=False,
    filled=True,
    radius_scale=3,
    radius_min_pixels=8,
    radius_max_pixels=20,
    line_width_min_pixels=1,
    get_position=["X", "Y"],
    get_fill_color="color",
    get_line_color=[0, 0, 0],
    radius_unit='pixels'
)

# Set the viewport location
view_state = pdk.ViewState(latitude=37.7749295, longitude=-122.4194155, zoom=11, bearing=0, pitch=0)

r = pdk.Deck(
    layers=[layer],
    initial_view_state=view_state,
    tooltip={
        "html": "{Descript} <br /> {Date}",  # Change tooltip text here
        "style": {
            "backgroundColor": "rgba(0, 0, 0, 0.7)",
            "color": "white",
            "fontFamily": "Helvetica, sans-serif"
        }
    }
)

# Render
r.to_html("MapPlot.html")
# Out:
#         <iframe
#             width="100%"
#             height=500
#             frameborder="0"
#             srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
#   &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;title&gt;pydeck&lt;/title&gt;
#         &lt;script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.13.0/mapbox-gl.js&quot;&gt;&lt;/script&gt;
#         &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot; /&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot; /&gt;
#     &lt;script src=&#x27;https://cdn.jsdelivr.net/npm/@deck.gl/jupyter-widget@~8.8.*/dist/index.js&#x27;&gt;&lt;/script&gt;
#     &lt;style&gt;
#     body {
#   margin: 0;
#   padding: 0;
#   overflow: hidden;
# }
#
# #deck-container {
#   width: 100vw;
#   height: 100vh;
# }
#
# #deck-container canvas {
#   z-index: 1;
#   background: none;
# }
#     &lt;/style&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;deck-container&quot;&gt;
#     &lt;/div&gt;
#   &lt;/body&gt;
#   &lt;script&gt;
#     const container = document.getElementById(&#x27;deck-container&#x27;);
#     const jsonInput = {
#   &quot;initialViewState&quot;: {
#     &quot;bearing&quot;: 0,
#     &quot;latitude&quot;: 37.7749295,
#     &quot;longitude&quot;: -122.4194155,
#     &quot;pitch&quot;: 0,
#     &quot;zoom&quot;: 11
#   },
#   &quot;layers&quot;: [
#     {
#       &quot;@@type&quot;: &quot;ScatterplotLayer&quot;,
#       &quot;data&quot;: [
#         {
#           &quot;Date&quot;: &quot;2014-04-03&quot;,
#           &quot;Descript&quot;: &quot;POSSESSION OF METH-AMPHETAMINE&quot;,
#           &quot;X&quot;: -122.405828840501,
#           &quot;Y&quot;: 37.7684749112706,
#           &quot;color&quot;: [
#             255,
#             187,
#             120
#           ],
#           &quot;drugtype&quot;: &quot;Methamphetamine&quot;
#         },
#         {
#           &quot;Date&quot;: &quot;2014-04-22&quot;,
#           &quot;Descript&quot;: &quot;SALE OF BASE/ROCK COCAINE&quot;,
#           &quot;X&quot;: -122.41792152803137,
#           &quot;Y&quot;: 37.78512010131991,
#           &quot;color&quot;: [
#             255,
#             152,
#             150
#           ],
#           &quot;drugtype&quot;: &quot;Base/rock cocaine&quot;
#         },
#         {
#           &quot;Date&quot;: &quot;2014-04-24&quot;,
#           &quot;Descript&quot;: &quot;POSSESSION OF HEROIN&quot;,
#           &quot;X&quot;: -122.391522893042,
#           &quot;Y&quot;: 37.7324323864471,
#           &quot;color&quot;: [
#             31,
#             119,
#             180
#           ],
#           &quot;drugtype&quot;: &quot;Heroin&quot;
#         },
#         {
#           &quot;Date&quot;: &quot;2014-04-24&quot;,
#           &quot;Descript&quot;: &quot;POSSESSION OF COCAINE&quot;,
#           &quot;X&quot;: -122.39535661130138,
#           &quot;Y&quot;: 37.73826162492951,
#           &quot;color&quot;: [
#             148,
#             103,
#             189
#           ],
#           &quot;drugtype&quot;: &quot;Cocaine&quot;
#         },
#         {
#           &quot;Date&quot;: &quot;2014-04-03&quot;,
#           &quot;Descript&quot;: &quot;POSSESSION OF HEROIN&quot;,
#           &quot;X&quot;: -122.40767142906884,
#           &quot;Y&quot;: 37.78009939873488,
#           &quot;color&quot;: [
#             31,
#             119,
#             180
#           ],
#           &quot;drugtype&quot;: &quot;Heroin&quot;
#         },
#         {
#           &quot;Date&quot;: &quot;2014-04-23&quot;,
#           &quot;Descript&quot;: &quot;POSSESSION OF NARCOTICS PARAPHERNALIA&quot;,
#           &quot;X&quot;: -122.4199371740388,
#           &quot;Y&quot;: 37.78698048447203,
#           &quot;color&quot;: [
#             196,
#             156,
#             148
#           ],
#           &quot;drugtype&quot;: &quot;Narcotics/Substance&quot;
#         },
#         {
#           &quot;Date&quot;: &quot;2014-04-23&quot;,
#           &quot;Descript&quot;: &quot;POSSESSION OF CONTROLLED SUBSTANCE&quot;,
#           &quot;X&quot;: -122.41389552627247,
#           &quot;Y&quot;: 37.782647628432386,
#           &quot;color&quot;: [
#             196,
#             156,
#             148
#           ],
#           &quot;drugtype&quot;: &quot;Narcotics/Substance&quot;
#         },
#         {
#           &quot;Date&quot;: &quot;2014-04-11&quot;,
#           &quot;Descript&quot;: &quot;POSSESSION OF BASE/ROCK COCAINE&quot;,
#           &quot;X&quot;: -122.40781298684378,
#           &quot;Y&quot;: 37.78008875722802,
#           &quot;color&quot;: [
#             255,
#             152,
#             150
#           ],
#           &quot;drugtype&quot;: &quot;Base/rock cocaine&quot;
#         },
#         {
#           &quot;Date&quot;: &quot;2014-04-02&quot;,
#           &quot;Descript&quot;: &quot;POSSESSION OF METH-AMPHETAMINE FOR SALE&quot;,
#           &quot;X&quot;: -122.41423184190482,
#           &quot;Y&quot;: 37.783864325914905,
#           &quot;color&quot;: [
#             255,
#             187,
#             120
#           ],
#           &quot;drugtype&quot;: &quot;Methamphetamine&quot;
#         },
#         {
#           &quot;Date&quot;: &quot;2014-04-05&quot;,
#           &quot;Descript&quot;: &quot;POSSESSION OF NARCOTICS PARAPHERNALIA&quot;,
#           &quot;X&quot;: -122.407085601172,
#           &quot;Y&quot;: 37.798151367711,
#           &quot;color&quot;: [
#             196,
#             156,
#             148
#           ],
#           &quot;drugtype&quot;: &quot;Narcotics/Substance&quot;
#         },
#         {
#           &quot;Date&quot;: &quot;2014-04-12&quot;,
#           &quot;Descript&quot;: &quot;SALE OF MARIJUANA&quot;,
#           &quot;X&quot;: -122.44700830213621,
#           &quot;Y&quot;: 37.77005274263337,
#           &quot;color&quot;: [
#             214,
#             39,
#             40
#           ],
#           &quot;drugtype&quot;: &quot;Marijuana&quot;
#         },
#         {
#           &quot;Date&quot;: &quot;2014-04-03&quot;,
#           &quot;Descript&quot;: &quot;POSSESSION OF METH-AMPHETAMINE&quot;,
#           &quot;X&quot;: -122.40773549182698,
#           &quot;Y&quot;: 37.78009902141745,
#           &quot;color&quot;: [
#             255,
#             187,
#             120
#           ],
#           &quot;drugtype&quot;: &quot;Methamphetamine&quot;
#         },
#         {
#           &quot;Date&quot;: &quot;2014-04-27&quot;,
#           &quot;Descript&quot;: &quot;POSSESSION OF METH-AMPHETAMINE&quot;,
#           &quot;X&quot;: -122.43015295597296,
#           &quot;Y&quot;: 37.76922919990392,
#           &quot;color&quot;: [
#             255,
#             187,
#             120
#           ],
#           &quot;drugtype&quot;: &quot;Methamphetamine&quot;
#         },
#         {
#           &quot;Date&quot;: &quot;2014-04-05&quot;,
#           &quot;Descript&quot;: &quot;POSSESSION OF NARCOTICS PARAPHERNALIA&quot;,
#           &quot;X&quot;: -122.41796629805849,
#           &quot;Y&quot;: 37.78562317231916,
#           &quot;color&quot;: [
#             196,
#             156,
#             148
#           ],
#           &quot;drugtype&quot;: &quot;Narcotics/Substance&quot;
#         },
#         {
#           &quot;Date&quot;: &quot;2014-04-13&quot;,
#           &quot;Descript&quot;: &quot;POSSESSION OF CONTROLLED SUBSTANCE FOR SALE&quot;,
#           &quot;X&quot;: -122.41370859220027,
#           &quot;Y&quot;: 37.78190488425096,
#           &quot;color&quot;: [
#             196,
#             156,
#             148
#           ],
#           &quot;drugtype&quot;: &quot;Narcotics/Substance&quot;
#         },
#         {
#           &quot;Date&quot;: &quot;2014-04-01&quot;,
#           &quot;Descript&quot;: &quot;POSSESSION OF CONTROLLED SUBSTANCE&quot;,
#           &quot;X&quot;: -122.41813475055035,
#           &quot;Y&quot;: 37.78570815479551,
#           &quot;color&quot;: [
#             196,
#             156,
#             148
#           ],
#           &quot;drugtype&quot;: &quot;Narcotics/Substance&quot;
#         },
#         {
#           &quot;Date&quot;: &quot;2014-04-25&quot;,
#           &quot;Descript&quot;: &quot;POSSESSION OF METH-AMPHETAMINE&quot;,
#           &quo

# %% [markdown]
# ## Plot 3: Normalised Drug Type Count against Police District

# %% [markdown]
# Normalising count for each district by drugtype:

# %%
disGroups = pd.DataFrame()
disGroups.index.name = 'District'

drugCrimesFilter = drugCrimes[drugCrimes['Date'].dt.year != 2018]

for i in labels:
    drugCrime = drugCrimesFilter[drugCrimesFilter['drugtype'] == i]
    disCount = drugCrime.groupby(drugCrime['PdDistrict']).size()
    disTotal = disCount.sum()
    disGroups[i] = disCount / disTotal

disGroups = disGroups.fillna(0)
disGroups.head()
# Out:
#              Heroin  Opium/Opiates  Prescription  Methamphetamine  \
# District
# BAYVIEW    0.081585       0.068279      0.025180         0.077300
# CENTRAL    0.020365       0.048364      0.068345         0.063736
# INGLESIDE  0.022476       0.036984      0.115108         0.087678
# MISSION    0.177946       0.170697      0.273381         0.162036
# NORTHERN   0.081460       0.064011      0.140288         0.162445
#
#            Amphetamine  Methadone  Marijuana  Base/rock cocaine   Cocaine  \
# District
# BAYVIEW       0.041978   0.063492   0.101715           0.080140  0.109805
# CENTRAL       0.074627   0.009524   0.028609           0.018784  0.047207
# INGLESIDE     0.093284   0.034921   0.059174           0.018394  0.072627
# MISSION       0.180037   0.130159   0.110847           0.179195  0.218572
# NORTHERN      0.173507   0.060317   0.049902           0.083228  0.095625
#
#            Barbituates  Hallucinogenic  Narcotics/Substance     Other
# District
# BAYVIEW       0.045455        0.050769             0.073276  0.032186
# CENTRAL       0.090909        0.033846             0.037386  0.088790
# INGLESIDE     0.000000        0.030769             0.035186  0.071032
# MISSION       0.272727        0.089231             0.162474  0.198668
# NORTHERN      0.136364        0.061538             0.091133  0.134295

# %% [markdown]
# Plotting this as bokeh interactive:

# %%
from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource, Legend, CustomJS, DatePicker
from bokeh.io import output_notebook, output_file
from bokeh.palettes import Category20_14
import math
from bokeh.layouts import column

# Create a Bokeh ColumnDataSource from the DataFrame
source = ColumnDataSource(disGroups)

output_file("DistrictDrugs.html")

# Create a Bokeh figure
p = figure(x_range=disGroups.index.values, height=400, width=800, title="Normalized Drug Crime Counts",
           toolbar_location=None, tools="", y_axis_label="Normalized Count")

# Rotate x-axis labels by 45 degrees
p.xaxis.major_label_orientation = math.pi / 4 

# Create an empty Legend object
legend = Legend()

# Add the legend to the plot on the right side
p.add_layout(legend, 'right')

# Plot vertical bars for each crime category
categories = list(disGroups.columns)

palette = [color for color in Category20_14]

bar = {}

for idx, i in enumerate(categories):
    bar[i] = p.vbar(x='District', top=i, source=source, width=0.5, legend_label=i,
           color=palette[idx], muted_color=palette[idx], fill_alpha=0.8, 
           muted_alpha=0.1, muted=True)

# Set attributes for the plot
p.y_range.start = 0
p.xaxis.axis_label = "Police District"
p.yaxis.axis_label = "Normalized Count"
p.legend.click_policy = "mute"
p.title.text_font = "Helvetica"
p.title.align = "center"
p.xaxis.axis_label_text_font = "Helvetica"
p.yaxis.axis_label_text_font = "Helvetica"
p.legend.label_text_font = "Helvetica"

show(p)
# Out:
#   <div id="c098f2c6-d05b-4960-a400-b49ca5ef6d1c" data-root-id="p4168" style="display: contents;"></div>

# %%
''
# Out:
# ''
